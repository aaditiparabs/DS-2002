# %% [markdown]
# # DS 2002 — Extra Credit Workshop
# ## MySQL + SQLAlchemy Sales Data Exploration
#
# **Instructions:** Work with your partner through each section. One person types, the other reviews and guides — switch roles at each new section.
#
# **How this works:** The first cell will automatically create a local database called `ds2002_workshop` on your machine and load a sample retail sales dataset. No external connections needed just your local MySQL.
#
# **Deliverable:** Screenshot your completed notebook (cells run, outputs visible) and submit it.
#
# ---

# %% [markdown]
# ## Setup: Create Database & Load Sample Data
#
# **Only thing you need to do:** Replace `YOUR_PASSWORD` with your MySQL root password, then run this cell.
#
# > This cell will create a database called `ds2002_workshop` and populate it with four tables: `customers`, `products`, `orders`, and `order_items`.

# %%
# Install dependencies if needed
# !pip install sqlalchemy pymysql pandas

import pandas as pd
from sqlalchemy import create_engine, text

# Replace with your MySQL root password
PASSWORD = "YOUR_PASSWORD"

# Step 1: Create the database 
base_engine = create_engine(f"mysql+pymysql://root:{PASSWORD}@localhost/")
with base_engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS ds2002_workshop"))
    conn.execute(text("COMMIT"))

# Step 2: Connect to new database 
engine = create_engine(f"mysql+pymysql://root:{PASSWORD}@localhost/ds2002_workshop")

# Step 3: Load sample data 

customers = pd.DataFrame([
    {"customer_id": 1,  "name": "Alice Martin",    "city": "Austin",       "state": "TX", "joined": "2022-03-15"},
    {"customer_id": 2,  "name": "Brian Lee",        "city": "Denver",       "state": "CO", "joined": "2021-07-22"},
    {"customer_id": 3,  "name": "Carmen Diaz",      "city": "Miami",        "state": "FL", "joined": "2023-01-10"},
    {"customer_id": 4,  "name": "David Kim",        "city": "Seattle",      "state": "WA", "joined": "2020-11-05"},
    {"customer_id": 5,  "name": "Elena Reyes",      "city": "Chicago",      "state": "IL", "joined": "2022-08-30"},
    {"customer_id": 6,  "name": "Frank Nguyen",     "city": "Houston",      "state": "TX", "joined": "2021-04-18"},
    {"customer_id": 7,  "name": "Grace Patel",      "city": "Boston",       "state": "MA", "joined": "2023-06-01"},
    {"customer_id": 8,  "name": "Henry Brooks",     "city": "Phoenix",      "state": "AZ", "joined": "2020-09-14"},
    {"customer_id": 9,  "name": "Isla Torres",      "city": "Portland",     "state": "OR", "joined": "2022-12-20"},
    {"customer_id": 10, "name": "James Wright",     "city": "Atlanta",      "state": "GA", "joined": "2021-02-07"},
    {"customer_id": 11, "name": "Karen Mills",      "city": "Dallas",       "state": "TX", "joined": "2023-03-25"},
    {"customer_id": 12, "name": "Liam Chen",        "city": "San Francisco","state": "CA", "joined": "2020-06-11"},
    {"customer_id": 13, "name": "Mia Johnson",      "city": "Nashville",    "state": "TN", "joined": "2022-10-03"},
    {"customer_id": 14, "name": "Noah Davis",       "city": "Charlotte",    "state": "NC", "joined": "2021-08-19"},
    {"customer_id": 15, "name": "Olivia Scott",     "city": "Las Vegas",    "state": "NV", "joined": "2023-05-08"}
])

products = pd.DataFrame([
    {"product_id": 1,  "product_name": "Wireless Headphones",  "category": "Electronics", "price": 89.99},
    {"product_id": 2,  "product_name": "USB-C Hub",             "category": "Electronics", "price": 45.00},
    {"product_id": 3,  "product_name": "Mechanical Keyboard",   "category": "Electronics", "price": 129.99},
    {"product_id": 4,  "product_name": "Webcam HD 1080p",       "category": "Electronics", "price": 72.50},
    {"product_id": 5,  "product_name": "Python Crash Course",   "category": "Books",       "price": 35.99},
    {"product_id": 6,  "product_name": "SQL for Data Science",  "category": "Books",       "price": 42.00},
    {"product_id": 7,  "product_name": "Clean Code",            "category": "Books",       "price": 38.50},
    {"product_id": 8,  "product_name": "Designing Data Systems","category": "Books",       "price": 55.00},
    {"product_id": 9,  "product_name": "Chef Knife Set",        "category": "Kitchen",     "price": 95.00},
    {"product_id": 10, "product_name": "French Press",          "category": "Kitchen",     "price": 32.00},
    {"product_id": 11, "product_name": "Cast Iron Skillet",     "category": "Kitchen",     "price": 48.75},
    {"product_id": 12, "product_name": "Air Fryer",             "category": "Kitchen",     "price": 119.99},
    {"product_id": 13, "product_name": "Running Shoes",         "category": "Clothing",    "price": 110.00},
    {"product_id": 14, "product_name": "Insulated Jacket",      "category": "Clothing",    "price": 145.00},
    {"product_id": 15, "product_name": "Yoga Pants",            "category": "Clothing",    "price": 65.00}
])

orders = pd.DataFrame([
    {"order_id": 1,  "customer_id": 3,  "order_date": "2024-01-05", "status": "completed"},
    {"order_id": 2,  "customer_id": 7,  "order_date": "2024-01-12", "status": "completed"},
    {"order_id": 3,  "customer_id": 1,  "order_date": "2024-01-20", "status": "completed"},
    {"order_id": 4,  "customer_id": 12, "order_date": "2024-02-03", "status": "completed"},
    {"order_id": 5,  "customer_id": 5,  "order_date": "2024-02-14", "status": "completed"},
    {"order_id": 6,  "customer_id": 9,  "order_date": "2024-02-22", "status": "cancelled"},
    {"order_id": 7,  "customer_id": 2,  "order_date": "2024-03-01", "status": "completed"},
    {"order_id": 8,  "customer_id": 14, "order_date": "2024-03-10", "status": "completed"},
    {"order_id": 9,  "customer_id": 6,  "order_date": "2024-03-18", "status": "completed"},
    {"order_id": 10, "customer_id": 11, "order_date": "2024-03-25", "status": "pending"},
    {"order_id": 11, "customer_id": 4,  "order_date": "2024-04-02", "status": "completed"},
    {"order_id": 12, "customer_id": 8,  "order_date": "2024-04-15", "status": "completed"},
    {"order_id": 13, "customer_id": 3,  "order_date": "2024-04-28", "status": "completed"},
    {"order_id": 14, "customer_id": 15, "order_date": "2024-05-06", "status": "completed"},
    {"order_id": 15, "customer_id": 10, "order_date": "2024-05-19", "status": "cancelled"},
    {"order_id": 16, "customer_id": 1,  "order_date": "2024-05-30", "status": "completed"},
    {"order_id": 17, "customer_id": 13, "order_date": "2024-06-07", "status": "completed"},
    {"order_id": 18, "customer_id": 7,  "order_date": "2024-06-21", "status": "completed"},
    {"order_id": 19, "customer_id": 12, "order_date": "2024-07-03", "status": "completed"},
    {"order_id": 20, "customer_id": 2,  "order_date": "2024-07-17", "status": "completed"},
    {"order_id": 21, "customer_id": 5,  "order_date": "2024-07-29", "status": "completed"},
    {"order_id": 22, "customer_id": 9,  "order_date": "2024-08-05", "status": "completed"},
    {"order_id": 23, "customer_id": 6,  "order_date": "2024-08-14", "status": "pending"},
    {"order_id": 24, "customer_id": 14, "order_date": "2024-08-26", "status": "completed"},
    {"order_id": 25, "customer_id": 4,  "order_date": "2024-09-09", "status": "completed"},
    {"order_id": 26, "customer_id": 11, "order_date": "2024-09-22", "status": "completed"},
    {"order_id": 27, "customer_id": 8,  "order_date": "2024-10-01", "status": "completed"},
    {"order_id": 28, "customer_id": 15, "order_date": "2024-10-14", "status": "cancelled"},
    {"order_id": 29, "customer_id": 3,  "order_date": "2024-10-28", "status": "completed"},
    {"order_id": 30, "customer_id": 13, "order_date": "2024-11-05", "status": "completed"},
    {"order_id": 31, "customer_id": 1,  "order_date": "2024-11-15", "status": "completed"},
    {"order_id": 32, "customer_id": 10, "order_date": "2024-11-25", "status": "completed"},
    {"order_id": 33, "customer_id": 7,  "order_date": "2024-12-02", "status": "completed"},
    {"order_id": 34, "customer_id": 12, "order_date": "2024-12-10", "status": "completed"},
    {"order_id": 35, "customer_id": 2,  "order_date": "2024-12-20", "status": "completed"}
])

order_items = pd.DataFrame([
    {"item_id": 1,  "order_id": 1,  "product_id": 5,  "quantity": 1},
    {"item_id": 2,  "order_id": 1,  "product_id": 10, "quantity": 2},
    {"item_id": 3,  "order_id": 2,  "product_id": 1,  "quantity": 1},
    {"item_id": 4,  "order_id": 2,  "product_id": 6,  "quantity": 1},
    {"item_id": 5,  "order_id": 3,  "product_id": 3,  "quantity": 1},
    {"item_id": 6,  "order_id": 3,  "product_id": 13, "quantity": 1},
    {"item_id": 7,  "order_id": 4,  "product_id": 14, "quantity": 1},
    {"item_id": 8,  "order_id": 4,  "product_id": 2,  "quantity": 2},
    {"item_id": 9,  "order_id": 5,  "product_id": 12, "quantity": 1},
    {"item_id": 10, "order_id": 5,  "product_id": 7,  "quantity": 1},
    {"item_id": 11, "order_id": 6,  "product_id": 9,  "quantity": 1},
    {"item_id": 12, "order_id": 7,  "product_id": 4,  "quantity": 1},
    {"item_id": 13, "order_id": 7,  "product_id": 8,  "quantity": 1},
    {"item_id": 14, "order_id": 8,  "product_id": 15, "quantity": 2},
    {"item_id": 15, "order_id": 8,  "product_id": 6,  "quantity": 1},
    {"item_id": 16, "order_id": 9,  "product_id": 11, "quantity": 1},
    {"item_id": 17, "order_id": 9,  "product_id": 1,  "quantity": 1},
    {"item_id": 18, "order_id": 10, "product_id": 3,  "quantity": 1},
    {"item_id": 19, "order_id": 11, "product_id": 14, "quantity": 1},
    {"item_id": 20, "order_id": 11, "product_id": 5,  "quantity": 2},
    {"item_id": 21, "order_id": 12, "product_id": 9,  "quantity": 1},
    {"item_id": 22, "order_id": 12, "product_id": 2,  "quantity": 1},
    {"item_id": 23, "order_id": 13, "product_id": 7,  "quantity": 1},
    {"item_id": 24, "order_id": 13, "product_id": 12, "quantity": 1},
    {"item_id": 25, "order_id": 14, "product_id": 13, "quantity": 1},
    {"item_id": 26, "order_id": 14, "product_id": 10, "quantity": 3},
    {"item_id": 27, "order_id": 15, "product_id": 4,  "quantity": 1},
    {"item_id": 28, "order_id": 16, "product_id": 3,  "quantity": 1},
    {"item_id": 29, "order_id": 16, "product_id": 15, "quantity": 1},
    {"item_id": 30, "order_id": 17, "product_id": 8,  "quantity": 1},
    {"item_id": 31, "order_id": 17, "product_id": 1,  "quantity": 2},
    {"item_id": 32, "order_id": 18, "product_id": 6,  "quantity": 1},
    {"item_id": 33, "order_id": 18, "product_id": 11, "quantity": 1},
    {"item_id": 34, "order_id": 19, "product_id": 14, "quantity": 1},
    {"item_id": 35, "order_id": 19, "product_id": 2,  "quantity": 3},
    {"item_id": 36, "order_id": 20, "product_id": 9,  "quantity": 1},
    {"item_id": 37, "order_id": 20, "product_id": 5,  "quantity": 1},
    {"item_id": 38, "order_id": 21, "product_id": 12, "quantity": 1},
    {"item_id": 39, "order_id": 21, "product_id": 7,  "quantity": 2},
    {"item_id": 40, "order_id": 22, "product_id": 13, "quantity": 1},
    {"item_id": 41, "order_id": 22, "product_id": 4,  "quantity": 1},
    {"item_id": 42, "order_id": 23, "product_id": 10, "quantity": 2},
    {"item_id": 43, "order_id": 24, "product_id": 3,  "quantity": 1},
    {"item_id": 44, "order_id": 24, "product_id": 15, "quantity": 1},
    {"item_id": 45, "order_id": 25, "product_id": 1,  "quantity": 1},
    {"item_id": 46, "order_id": 25, "product_id": 8,  "quantity": 1},
    {"item_id": 47, "order_id": 26, "product_id": 11, "quantity": 2},
    {"item_id": 48, "order_id": 26, "product_id": 6,  "quantity": 1},
    {"item_id": 49, "order_id": 27, "product_id": 14, "quantity": 1},
    {"item_id": 50, "order_id": 27, "product_id": 5,  "quantity": 2},
    {"item_id": 51, "order_id": 28, "product_id": 9,  "quantity": 1},
    {"item_id": 52, "order_id": 29, "product_id": 2,  "quantity": 1},
    {"item_id": 53, "order_id": 29, "product_id": 13, "quantity": 1},
    {"item_id": 54, "order_id": 30, "product_id": 7,  "quantity": 1},
    {"item_id": 55, "order_id": 30, "product_id": 12, "quantity": 1},
    {"item_id": 56, "order_id": 31, "product_id": 3,  "quantity": 1},
    {"item_id": 57, "order_id": 31, "product_id": 4,  "quantity": 1},
    {"item_id": 58, "order_id": 32, "product_id": 1,  "quantity": 1},
    {"item_id": 59, "order_id": 32, "product_id": 15, "quantity": 2},
    {"item_id": 60, "order_id": 33, "product_id": 8,  "quantity": 1},
    {"item_id": 61, "order_id": 33, "product_id": 6,  "quantity": 2},
    {"item_id": 62, "order_id": 34, "product_id": 14, "quantity": 2},
    {"item_id": 63, "order_id": 34, "product_id": 10, "quantity": 1},
    {"item_id": 64, "order_id": 35, "product_id": 11, "quantity": 1},
    {"item_id": 65, "order_id": 35, "product_id": 9,  "quantity": 1}
])

# Write all tables to MySQL (replace if they already exist)
customers.to_sql("customers",   engine, if_exists="replace", index=False)
products.to_sql("products",     engine, if_exists="replace", index=False)
orders.to_sql("orders",         engine, if_exists="replace", index=False)
order_items.to_sql("order_items", engine, if_exists="replace", index=False)

print("Database ready! Tables created:")
print(f"  customers   → {len(customers)} rows")
print(f"  products    → {len(products)} rows")
print(f"  orders      → {len(orders)} rows")
print(f"  order_items → {len(order_items)} rows")

# %% [markdown]
# ---
# ## Quick Look at the Tables
#
# Always explore your data before writing queries.

# %%
# Preview tables
for table in ["customers", "products", "orders", "order_items"]:
    print(f"\n--- {table.upper()} (first 3 rows) ---")
    df = pd.read_sql(f"SELECT * FROM {table} LIMIT 3", engine)
    display(df)

# %% [markdown]
# ---
# ## What Can We Uncover Here?
#
# You're now looking at a year's worth of transactional data from a small retail business the kind of data that sits inside the backend of any e-commerce platform, POS system, or CRM. On its own, each table tells you very little: a list of customers, a list of products, a log of orders. But once you start joining these tables together and aggregating across them, you can answer the kinds of questions that actually drive business decisions. Who are our most valuable customers, and where do they live? Which product categories are generating the most revenue versus the most volume and are those the same thing? Are there customers we haven't heard from in months? Do buying patterns differ by state? Do sales spike at certain times of year? Which states should we put the majority of the marketing fund to yield the highest profit?
#
# This is exactly what a data analyst, data engineer, business analyst, may get handed on day one at a company, a relational database (hopefully) with a few core tables and a list of questions from the business side. Your job in the next 15-25 minutes is to practice thinking that way: not just writing syntactically correct SQL, but writing queries that actually answer something meaningful. The questions below are designed to build on each other, so think about what each result is telling you, not just whether the code ran.

# %% [markdown]
# ---
# ## Question 1: JOIN — Order Summary
#
# **Task:** Write a query that returns a summary of all **completed** orders. Your result should include:
# - The customer's **name** and **state**
# - The **order date**
# - The **total number of items** in that order (sum of quantities)
# - The **total order value** (sum of quantity × price for each item)
#
# Sort by total order value from **highest to lowest**.
#
# > *Hint: You'll need to JOIN all four tables. Start by thinking about which tables connect to which, then build your JOIN chain. Use `WHERE` to filter for completed orders only.*

# %%
query_1 = """
-- Write your query here

"""

df_q1 = pd.read_sql(query_1, engine)
df_q1

# %% [markdown]
# **Discussion:** Which order had the highest value? Does anything about the results surprise you?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
# ## Question 2: Aggregation — Top 5 Customers by Spending
#
# **Task:** Find the **top 5 customers** by total amount spent across all their **completed** orders.
#
# Your result should include:
# - Customer **name** and **city**
# - **Total number of orders** they placed
# - **Total amount spent** (rounded to 2 decimal places)
#
# > *Hint: Use `GROUP BY` on the customer, `SUM()` for total spend, `COUNT(DISTINCT ...)` for number of orders, and `HAVING` or a `WHERE` to filter for completed orders. `ROUND()` can clean up the dollar amounts.*

# %%
query_2 = """
-- Write your query here

"""

df_q2 = pd.read_sql(query_2, engine)
df_q2

# %% [markdown]
# **Discussion:** Who is the top customer? What city are most of the top spenders from?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
# ## Question 3: Category Revenue & Monthly Trends
#
# **Task:** Write a query that shows **total revenue by product category**, but only for completed orders. Include:
# - **Category name**
# - **Number of units sold**
# - **Total revenue** for that category (rounded to 2 decimal places)
#
# Sort by total revenue descending.
#
# > *Hint: You only need `products`, `order_items`, and `orders` for this one. Think about what you're grouping on and how revenue = quantity × price.*

# %%
query_3 = """
-- Write your query here

"""

df_q3 = pd.read_sql(query_3, engine)
df_q3

# %% [markdown]
# **Discussion:** Which category drives the most revenue? Which drives the least? Why might that be?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
# ## Open-Ended Query 1: Your Choice
#
# Come up with your own question about this dataset and write a query to answer it. Some ideas:
#
# - Which month in 2024 had the highest total sales?
# - What is the most frequently purchased product?
# - Which state has the highest average order value?
# - How many orders were cancelled vs. completed vs. pending?
# - Which customers have only ever placed one order?
#
# **Write your question below, then the query, then interpret the result.**

# %% [markdown]
# **Our question:** *Write your question here...*

# %%
query_open1 = """
-- Your query here

"""

df_open1 = pd.read_sql(query_open1, engine)
df_open1

# %% [markdown]
# **What did you find?**

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
# ## Open-Ended Query 2: Go Deeper
#
# Build on your first open-ended query OR start something new. This time, try to use at least one concept you haven't used yet in this notebook — a subquery, a `CASE` statement, `HAVING`, a date function, or a self-join.
#
# **Write your question, query, and interpretation.**

# %% [markdown]
# **Our question:** *Write your question here...*

# %%
query_open2 = """
-- Your query here

"""

df_open2 = pd.read_sql(query_open2, engine)
df_open2

# %% [markdown]
# **What did you find? (2–3 sentences)**

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# ---
# ## Done!
#
# Make sure all cells are run, discussion cells are filled in, then take your screenshot for submission.

# %%
engine.dispose()
print("Connection closed. Great work!")
